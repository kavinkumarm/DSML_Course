# %% [markdown]
# **Need Of Function**

# %% [markdown]
# *   Relative 1 is coming to home , Parents giving instruction to his Son

# %%
print("Dust all the Rooms")
print("Arrance the Living Areas")
print("Don't Misbehave infront of the guests")
print("Great them when they enter")
# Out:
# Dust all the Rooms
# Arrance the Living Areas
# Don't Misbehave infront of the guests
# Great them when they enter

# %% [markdown]
# *   Relative 2 is coming to home tomorrow , Parents giving instruction to his Son.
# *   Here there is repeatation is same set of instuctions. So functions comes to handy

# %%
print("Dust all the Rooms")
print("Arrance the Living Areas")
print("Don't Misbehave infront of the guests")
print("Great them when they enter")
# Out:
# Dust all the Rooms
# Arrance the Living Areas
# Don't Misbehave infront of the guests
# Great them when they enter

# %% [markdown]
# **What is Functions**

# %%
#Functions --> designed to perorm a designated task or functionalities
#Do you know? print(), len() are build in functions.
#Method or function both are same.
#Below ingase is the syntax.
#One Intentation required in function body
#Basic Usecase of funtion : code re-usability

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def guest_preparation():
  print("Dust all the Rooms")
  print("Arrance the Living Areas")
  print("Don't Misbehave infront of the guests")
  print("Great them when they enter")

# %%
guest_preparation() #Function calling --> To call the functionality and print the instructions
# Out:
# Dust all the Rooms
# Arrance the Living Areas
# Don't Misbehave infront of the guests
# Great them when they enter

# %%
#Second guest also call the same function
#Imagine like parents write the instatuction in the Chart paper , if each time new guest came,
#They just show to you
guest_preparation()
# Out:
# Dust all the Rooms
# Arrance the Living Areas
# Don't Misbehave infront of the guests
# Great them when they enter

# %%
#What is the output
def solve():
  print("1")
  print("2")
print("3")
# Out:
# 3

# %% [markdown]
# Why 1 and 2 not printed?\
# Function is not yet called

# %%
solve() #Function calling
# Out:
# 1
# 2

# %%
#What is the output
def solve():
  print("1")
  print("2")
solve()
print("3")
# Out:
# 1
# 2
# 3

# %% [markdown]
# **Concept of parameter:**\
# Greet funtion must greet each person

# %%
def great():
  print("Welcome to the App , Kavin!")

# %%
great()
# Out:
# Welcome to the App , Kavin!

# %% [markdown]
# The above greet function is static it is not used to greet the another person Ashwin\
# Here is the concept of paramer comes to the picture

# %% [markdown]
# **Example program**

# %%
'''
Question:
Take a name as an input
Write a greeting function that prints "Hello name" after accepting the name as a parameter

ip: AJ
op: Hello AJ

ip: Vinit
op: Hello Vinit
'''
# Out:
# '\nQuestion:\nTake a name as an input\nWrite a greeting function that prints "Hello name" after accepting the name as a parameter\n\nip: AJ\nop: Hello AJ\n\nip: Vinit\nop: Hello Vinit\n'

# %%
name = input()
# Out:
# Kavin

# %%
print(name)
# Out:
# Kavin

# %%
def great_person(name):
  print("Hello",name) #variable name must be same , what we received in fun definition

# %%
great_person("Kavin")
# Out:
# Hello Kavin

# %%
great_person("Ashwin") #Now problem is solved the same piece of code used for any person
# Out:
# Hello Ashwin

# %%
n = input()
great_person(n) # n and variable 'name' need to be same
# Out:
# Vijay
# Hello Vijay

# %%
'''
Create the function to print the specification of a car
color
brand
price
'''
# Out:
# '\nCreate the function to print the specification of a car\ncolor\nbrand\nprice\n'

# %%
def car_specs(color,brand,price):
  print("Color:",color)
  print("Brand:",brand)
  print("Price:",price)

# %%
car_specs("Red","BMW",1000000) #Positinal Argument
# Red is mapped to color
# BMW is mapped to brand
# 1000000 is mapped to price
# Out:
# Color: Red
# Brand: BMW
# Price: 1000000

# %%
car_specs("Blue","Land Rover",1500000) #Positinal Argument
# Out:
# Color: Blue
# Brand: Land Rover
# Price: 1500000

# %%
car_specs("Orange",17000000,"lamborghini") #Positinal Argument
# Out:
# Color: Orange
# Brand: 17000000
# Price: lamborghini

# %% [markdown]
# Positional Argument : POISITION OR ORDER MATTERS
#
# Issue : We have always remember the ORDER of the Argument in the function definition/
#
# Solution : Key-worded Argument
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Understanding the Errors**

# %%
def car_specs(color,brand,price):
  print("Color:",color)
  print("Brand:",brand)
  print("Price:",price)

# %%
car_specs("Red","BMW") # one Argument missing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-267cec83ddf0> in <cell line: 1>()
# ----> 1 car_specs("Red","BMW") # one Argument missing
#
# TypeError: car_specs() missing 1 required positional argument: 'price'

# %%
car_specs("Red","BMW",1500000,"28% Import tax") # one Argument extra
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-74ff2f589f86> in <cell line: 1>()
# ----> 1 car_specs("Red","BMW",1500000,"28% Import tax") # one Argument extra
#
# TypeError: car_specs() takes 3 positional arguments but 4 were given

# %% [markdown]
# in positinal argument Number of arguments or number of parameters needs to be exactly same

# %%
#Quiz 1

# %%
def solve(a,b,c):
  print(a)
  print(b)
  print(c)

# %%
solve(1,2,3)
# Out:
# 1
# 2
# 3

# %%
solve(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-c7791ddb1435> in <cell line: 1>()
# ----> 1 solve(1,2)
#
# TypeError: solve() missing 1 required positional argument: 'c'

# %%
solve(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-efc3d3c1c60c> in <cell line: 1>()
# ----> 1 solve(1,2,3,4)
#
# TypeError: solve() takes 3 positional arguments but 4 were given

# %%
#Quiz 2

# %%
#Quiz: What will be the output of the following code?

def factorial(n):
    result = 1
    while n > 0:
        result *= n
        n -= 1

    print(result)

factorial(5)


'''
Options:
A: 40
B: 24
C: 120
D: 100
'''
# Out:
# 120
# '\nOptions:\nA: 40\nB: 24\nC: 120\nD: 100\n'

# %% [markdown]
# **Understaning the Function Return values**

# %%
#Factorial N numbers
def factorial(n):
    result = 1
    while n > 0:
        result *= n
        n -= 1

    print(result)

factorial(5) # 5*4*2*1
# Out:
# 120

# %%
#Quiz: What will be the output of the following code?

def factorial(n):
    result = 1
    while n > 0:
        result *= n
        n -= 1

print(factorial(5))
# Out:
# None

# %% [markdown]
# **Why None is output?**
#
# Understand the return vs print
#
# print: show/display the value
# -> Value is displayed whenever print is called
#
# return: actually returns the value
# -> value can be stored in a variable to be used further
#
# If Nothing is returned by Function None is returned by deault

# %% [markdown]
# **Example 1**

# %%
def accept_money(amount):
  print(2*amount)

# %%
accept_money(100)
# Out:
# 200

# %%
wallet = accept_money(100)
# Out:
# 200

# %%
print(wallet)
# Out:
# None

# %% [markdown]
# **Example 2**

# %%
def accept_money(amount):
  return 2*amount

# %%
wallet = accept_money(100)

# %%
print(wallet)
# Out:
# 200

# %% [markdown]
# return --> returns back the value to where it was called from\
# return --> it ends/terminates the function at that line

# %%
#Quiz: What will be the value of b after the code is completed
def solve(a):
  print(2*a)
  return 1

# %%
b = solve(5)
# Out:
# 10

# %%
print(b)
# Out:
# 1

# %%
def sample():
  print("Hi")
  return 1 #it ends/terminates the function at that line
  print("Bye")
  print("Kavin")

# %%
ans = sample()
# Out:
# Hi

# %% [markdown]
# **System defined functions**

# %%
print("Kavin")
# Out:
# Kavin

# %%
type(1)
# Out:
# int

# %%
a = max(1,2,3,88)
print(a)
# Out:
# 88

# %% [markdown]
# **DocStrings**
#
# It gives more infomartion about the functions

# %%
def add_values(a,b):
  res = a+b
  print(res)

# %%
add_values(1,3) #passing integer
# Out:
# 4

# %%
("Kavin ","Kumar") #passing stringadd_values
# Out:
# Kavin Kumar

# %%
add_values(1,"Kavin")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-a13223d4a3f7> in <cell line: 1>()
# ----> 1 add_values(1,"Kavin")
#
# <ipython-input-72-28cb315a382a> in add_values(a, b)
#       1 def add_values(a,b):
# ----> 2   res = a+b
#       3   print(res)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Adding the docstrins to the Functions

# %%
def add_values(a,b):

  '''
  Arguments:
  a: int or str
  b: int or str

  Note: please do not enter diff data types in one function call. Either call it with both strings, or with both int

  output:
  str + str --> concatenation
  int + int --> addition
  '''

  res = a+b
  print(res)

# %%
add_values(1,3) #passing integer
# Out:
# 4

# %%
help(add_values) #To get the docstrings
# Out:
# Help on function add_values in module __main__:
#
# add_values(a, b)
#     Arguments:
#     a: int or str
#     b: int or str
#
#     Note: please do not enter diff data types in one function call. Either call it with both strings, or with both int
#
#     output:
#     str + str --> concatenation
#     int + int --> addition

# %% [markdown]
# **Quiz 1**

# %%
def do_something(n):
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1

    return total

print(do_something(5))
# Out:
# 15
